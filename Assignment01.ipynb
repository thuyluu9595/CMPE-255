# %%
# !pip install pandas numpy matplotlib scipy seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("used_cars_data.csv")
df
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %% [markdown]
# # Question 1 Data cleaning

# %%
# Removing columns: 'S.No' and 'New_Price'
df.drop(columns=['S.No.', 'New_Price'], inplace= True)
df
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
# Adding a feature named 'Car_Age'
cur_year = 2025
df['Car_Age'] = cur_year - df['Year']
df
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
# Filling missing values for electric vehicle (EV)
# Identify missing Mileage for EV 
df.query("Fuel_Type == 'Electric'")
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type Mileage   Engine   Power  Seats  Price  Car_Age
# 4446    Automatic      First     NaN    72 CC  41 bhp    5.0  13.00        9
# 4904    Automatic      First     NaN  1798 CC  73 bhp    5.0  12.75       14

# %%
# Driving range of Mahindra E Verito D4 is 140 km and battery capacity is 18.55kWh. 
# Source: https://www.carwale.com/mahindra-cars/verito/e-d4-2016-2019/
df.loc[4446, 'Mileage'] = "140 kmpl"

# Driving range of Toyota Prius Z4 is 23.91 kmpl. 
# Source: https://www.cardekho.com/toyota/prius-2009-2016/mileage
df.loc[4904, 'Mileage'] = "23.91 kmpl"
df.query("Fuel_Type == 'Electric'")
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type     Mileage   Engine   Power  Seats  Price  \
# 4446    Automatic      First    140 kmpl    72 CC  41 bhp    5.0  13.00
# 4904    Automatic      First  23.91 kmpl  1798 CC  73 bhp    5.0  12.75
#
#       Car_Age
# 4446        9
# 4904       14

# %% [markdown]
# # Question 2 Transformation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7253 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  Price              6019 non-null   float64
#  12  Car_Age            7253 non-null   int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 736.8+ KB

# %% [markdown]
# ### Transform Mileage column

# %%
df['Mileage'].str.extract(r'(\D+)$')[0].value_counts()
# Out:
# 0
# kmpl     7179
# km/kg      74
# Name: count, dtype: int64

# %%
# In the Mileage column, because kmpl is the dominant unit, all values will be converted to kmpl
# Extract number from Mileage and put in a new column named Mileage_Value
df['Mileage_Value'] = df['Mileage'].str.extract(r'(\d+\.?\d*)')[0].astype(float)
# Extract unit into a new column named Mileage_Unit
df['Mileage_Unit'] = df['Mileage'].str.extract(r'(\D+)$').astype(str)[0].str.strip()
# Conversion dictionary
rate = {
    'kmpl': 1,
    'km/kg': 1.4
}
# Convert all values to kmpl
df['Mileage_kmpl'] = df.apply(lambda row: row['Mileage_Value'] * rate.get(row['Mileage_Unit'], 1), axis=1)

# Drop all created columns and rename Mileage_kmpl to Mileage
df.drop(columns=['Mileage', 'Mileage_Value', 'Mileage_Unit'], inplace=True)
df.rename(columns={'Mileage_kmpl': 'Mileage'}, inplace=True)
df.head(30)
# Out:
#                                                 Name    Location  Year  \
# 0                             Maruti Wagon R LXI CNG      Mumbai  2010
# 1                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                       Honda Jazz V     Chennai  2011
# 3                                  Maruti Ertiga VDI     Chennai  2012
# 4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                             Nissan Micra Diesel XV      Jaipur  2013
# 7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                  Maruti Ciaz Zeta       Kochi  2018
# 11                       Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %% [markdown]
# ### Transform Engine Column

# %%
df['Engine'].str.extract(r'(\D+)$')[0].value_counts()
# Out:
# 0
# CC    7207
# Name: count, dtype: int64

# %%
# Because there is only one unit in Engine column, unit conversion is not needed for Engine column
df['Engine'] = df['Engine'].str.extract(r'(\d+\.?\d*)')[0]
df['Engine'] = pd.to_numeric(df['Engine'], errors='coerce').astype('Int64')
df.head(20)
# Out:
#                                                 Name    Location  Year  \
# 0                             Maruti Wagon R LXI CNG      Mumbai  2010
# 1                   Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                       Honda Jazz V     Chennai  2011
# 3                                  Maruti Ertiga VDI     Chennai  2012
# 4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                    Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                             Nissan Micra Diesel XV      Jaipur  2013
# 7                  Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                     Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                  Maruti Ciaz Zeta       Kochi  2018
# 11                       Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %% [markdown]
# ### Transform Power column

# %%
df['Power'].str.extract(r'(\D+)$')[0].value_counts()
# Out:
# 0
#  bhp        7078
# null bhp     129
# Name: count, dtype: int64

# %%
# Since there is only one unit, which is bhp, no unit conversion needed for Power column
df['Power'] = df['Power'].str.extract(r'(\d+\.?\d*)')[0]
df['Power'] = pd.to_numeric(df['Power'], errors='coerce').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Engine             7207 non-null   Int64
#  8   Power              7078 non-null   float64
#  9   Seats              7200 non-null   float64
#  10  Price              6019 non-null   float64
#  11  Car_Age            7253 non-null   int64
#  12  Mileage            7253 non-null   float64
# dtypes: Int64(1), float64(4), int64(3), object(5)
# memory usage: 743.8+ KB

# %% [markdown]
# # Question 3: Outlier Detection and box-plot

# %% [markdown]
# ### Check normal distribution or non-normal distribution for the following columns: 'Car_Age', 'Kilometer_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Price'

# %%
# Visualize the date of each column by drawing histograms
def visualize_distribution(column):
    sns.histplot(df[column].dropna(), kde=True, bins=50)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'{column} Histogram')
    plt.show()

column_list = ['Car_Age', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats', 'Price']
for column in column_list:
    visualize_distribution(column)

# %%
import scipy.stats as stats
# Since there are over 7000 records of data, D'Agostino and Pearson's Test is used to check normality
def test_normality(df, columns):
    result = []
    for col in columns:
        data = df[col].dropna()

        stat, p_value = stats.normaltest(data)
        is_normality = p_value > 0.05
        result.append({'Column': col, 'Normality': is_normality, 'p_value': p_value})
    return pd.DataFrame(result)
normality_test_result = test_normality(df, column_list)
normality_test_result.head(len(column_list))
# Out:
#               Column  Normality        p_value
# 0            Car_Age      False  3.564033e-170
# 1  Kilometers_Driven      False   0.000000e+00
# 2            Mileage      False   0.000000e+00
# 3             Engine      False   0.000000e+00
# 4              Power      False   0.000000e+00
# 5              Seats      False   0.000000e+00
# 6              Price      False   0.000000e+00

# %% [markdown]
# #### Conclusion: From the Histograms and statistic test with D'Agostino and Pearson's Test, we can conclude that all tested columns are non-normal distribution

# %% [markdown]
# ### Detect outliers and print number of outliers for each column

# %% [markdown]
# #### Since all data columns are not normally distributed, the formulas lower_limit = Q1 - 1.5*IQR and upper_limit = Q3 + 1.5*IQR will be applied to detect outliers

# %%
# Calculate lower and upper limit for each column
def calculate_limits(df, columns):
    result = []
    for col in columns:
        data = df[col].dropna()

        # Calculate Q1
        q1 = np.quantile(data, 0.25)

        # Calculate Q3
        q3 = np.quantile(data, 0.75)

        # Calculate IQR
        iqr = q3 - q1

        # Calculate lower limit
        lower_limit = q1 - 1.5 * iqr

        # Calculate upper limit
        upper_limit = q3 + 1.5 * iqr

        result.append({'Column': col, 'Lower Limit': lower_limit, 'Upper Limit': upper_limit})
    return pd.DataFrame(result)
limits = calculate_limits(df, column_list)
limits.head(len(column_list))
# Out:
#               Column  Lower Limit  Upper Limit
# 0            Car_Age        1.500       21.500
# 1  Kilometers_Driven   -24500.000   131500.000
# 2            Mileage        6.500       29.860
# 3             Engine       43.000     3123.000
# 4              Power      -19.650      232.750
# 5              Seats        5.000        5.000
# 6              Price       -6.175       19.625

# %%
# Detect outliers for each column
def detect_outliers(df, columns):
    outliers = []
    for col in columns:
        data = df[col].dropna()

        # Filter outliers
        outlier = data[(data < limits[limits['Column'] == col]['Lower Limit'].values[0]) | (data > limits[limits['Column'] == col]['Upper Limit'].values[0])]

        outliers.append({'Column': col, 'Number of Outliers': len(outlier)})
    return pd.DataFrame(outliers)
outliers = detect_outliers(df, column_list)
outliers.head(len(column_list))
# Out:
#               Column  Number of Outliers
# 0            Car_Age                  58
# 1  Kilometers_Driven                 258
# 2            Mileage                 134
# 3             Engine                  65
# 4              Power                 273
# 5              Seats                1153
# 6              Price                 718

# %% [markdown]
# ### Draw box-plot for each column

# %%
# Draw box-plots
def draw_boxplot(df, columns):
    data = []
    for col in columns:
        data.append(df[col].dropna())

    sns.boxplot(data)
    plt.ylabel('Values')
    plt.title(f'Box-plot of column {columns}')
    plt.xticks(columns)
    plt.show()

draw_boxplot(df, ['Price', 'Mileage'])
draw_boxplot(df, ['Seats', 'Car_Age'])
draw_boxplot(df, ['Engine'])
draw_boxplot(df, ['Power'])
draw_boxplot(df, ['Kilometers_Driven'])

# %%
# Draw box-plot for Mileage and Fuel_Type
draw_boxplot(df, ['Mileage', 'Fuel_Type'])

# %% [markdown]
# # Question 4: Pearson correlation coefficient and scatter plot
